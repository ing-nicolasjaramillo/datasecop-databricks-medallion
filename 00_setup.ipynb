-- %%
USE CATALOG workspace_practica_1;
CREATE SCHEMA IF NOT EXISTS secop_bronze;
CREATE SCHEMA IF NOT EXISTS secop_silver;
CREATE SCHEMA IF NOT EXISTS secop_gold;
CREATE VOLUME IF NOT EXISTS secop_bronze.raw;
